# %% [markdown]
# <a href="https://colab.research.google.com/github/ChloeLeng/Kaggle-Datasets/blob/main/Netflix_TV_Shows_and_Movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Load Dataset

# %%
credits  = pd.read_csv('credits.csv')
credits
# Out:
#        person_id         id                    name                character  \
# 0           3748    tm84618          Robert De Niro            Travis Bickle
# 1          14658    tm84618            Jodie Foster            Iris Steensma
# 2           7064    tm84618           Albert Brooks                      Tom
# 3           3739    tm84618           Harvey Keitel  Matthew 'Sport' Higgins
# 4          48933    tm84618         Cybill Shepherd                    Betsy
# ...          ...        ...                     ...                      ...
# 77208    1347054  tm1098060  Nnenna Rachael Okonkwo                   Afinni
# 77209     157590  tm1098060           Lucien Morgan           Dr. Ian Stones
# 77210     129059  tm1098060        Magdalena Korpas                     Jane
# 77211    2050199  tm1098060        Mistura Olusanya               Nurse Titi
# 77212    2050423  tm1098060              Yemi Amodu                      NaN
#
#            role
# 0         ACTOR
# ...

# %%
titles = pd.read_csv('titles.csv')
titles.head(5)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm127384      Monty Python and the Holy Grail  MOVIE
# 3   tm70993                        Life of Brian  MOVIE
# 4  tm190788                         The Exorcist  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  King Arthur, accompanied by his squire, recrui...          1975
# 3  Brian Cohen is an average young Jewish man, bu...          1979
# 4  12-year-old Regan MacNeil begins to adapt an e...          1973
#
#   age_certification  runtime                 genres production_countries  \
# 0             TV-MA       48      ['documentation']               ['US']
# 1                 R      113     ['crime', 'drama']               ['US']
# ...

# %% [markdown]
# Merge two datasets into one

# %%
data = pd.merge(titles,credits)
data.head(10)
# Out:
#         id        title   type  \
# 0  tm84618  Taxi Driver  MOVIE
# 1  tm84618  Taxi Driver  MOVIE
# 2  tm84618  Taxi Driver  MOVIE
# 3  tm84618  Taxi Driver  MOVIE
# 4  tm84618  Taxi Driver  MOVIE
# 5  tm84618  Taxi Driver  MOVIE
# 6  tm84618  Taxi Driver  MOVIE
# 7  tm84618  Taxi Driver  MOVIE
# 8  tm84618  Taxi Driver  MOVIE
# 9  tm84618  Taxi Driver  MOVIE
#
#                                          description  release_year  \
# 0  A mentally unstable Vietnam War veteran works ...          1976
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  A mentally unstable Vietnam War veteran works ...          1976
# 3  A mentally unstable Vietnam War veteran works ...          1976
# 4  A mentally unstable Vietnam War veteran works ...          1976
# 5  A mentally unstable Vietnam War veteran works ...          1976
# 6  A mentally unstable Vietnam War veteran works ...          1976
# 7  A mentally unstable Vietnam War veteran works ...          1976
# ...

# %% [markdown]
# #Explore Data

# %%
data.shape
# Out:
# (77213, 19)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77213 entries, 0 to 77212
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    77213 non-null  object
#  1   title                 77212 non-null  object
#  2   type                  77213 non-null  object
#  3   description           77160 non-null  object
#  4   release_year          77213 non-null  int64
#  5   age_certification     46595 non-null  object
#  6   runtime               77213 non-null  int64
#  7   genres                77213 non-null  object
#  8   production_countries  77213 non-null  object
#  9   seasons               13976 non-null  float64
#  10  imdb_id               73388 non-null  object
#  11  imdb_score            72937 non-null  float64
#  12  imdb_votes            72850 non-null  float64
#  13  tmdb_popularity       77202 non-null  float64
#  14  tmdb_score            76093 non-null  float64
# ...

# %% [markdown]
# ##Check the null values

# %%
credits.isnull()
# Out:
#               id   name  character   role
# person_id
# 3748       False  False      False  False
# 14658      False  False      False  False
# 7064       False  False      False  False
# 3739       False  False      False  False
# 48933      False  False      False  False
# ...          ...    ...        ...    ...
# 1347054    False  False      False  False
# 157590     False  False      False  False
# 129059     False  False      False  False
# 2050199    False  False      False  False
# 2050423    False  False       True  False
#
# [77213 rows x 4 columns]

# %%
credits.isnull().sum()
# Out:
# id              0
# name            0
# character    9627
# role            0
# dtype: int64

# %% [markdown]
# #Question1: How many Movies and How many Shows are there on Netflix? Plot a graph to show the difference

# %%
movie = data["type"]=='MOVIE'
number_of_movies = sum(movie==True)
show = data['type'] == 'SHOW'
number_of_shows = sum(show==True)

# %% [markdown]
# After counting the number of each, we can now plot the graph

# %%
import matplotlib.pyplot as plt
x = ["Movies","Shows"]
y = [number_of_movies, number_of_shows]
print("Number of Movies is: "+str(number_of_movies))
print("Number of Shows is: "+str(number_of_shows))
plt.bar(x,y)
plt.show()
# Out:
# Number of Movies is: 63237
# Number of Shows is: 13976

# %% [markdown]
# #Question 2: In Which year most movies or series were released?

# %% [markdown]
# To calculate in which year the most movies or series were released, we are going to run the loop to go through the data and calculat the count of each year and then plot that in graph

# %%
years = []
year_count = []
release_year = data["release_year"].drop_duplicates()


for year in release_year:
    count = 0
    for index in range(0,len(data["release_year"])):
        if year == data["release_year"][index]:
            count +=1
    years.append(year)
    year_count.append(count)
print(years)
# Out:
# [1976, 1975, 1979, 1973, 1969, 1971, 1964, 1980, 1967, 1966, 1961, 1954, 1958, 1968, 1977, 1972, 1963, 1960, 1956, 1953, 1974, 1959, 1962, 1978, 1986, 1989, 1984, 1990, 1987, 1983, 1982, 1981, 1988, 1985, 1995, 2000, 1997, 1994, 1996, 1999, 1998, 1993, 1992, 1991, 2008, 2010, 2004, 2005, 2003, 2009, 2007, 2006, 2001, 2002, 2012, 2011, 2014, 2013, 2015, 2016, 2017, 2018, 2019, 2020, 2022, 2021]

# %%
#Creating table for each year
x = years
y = year_count
# create a new dataframe
d = {"Year":years,"Release per year":year_count}
df = pd.DataFrame(d)
df.sort_values("Release per year",axis = 0,inplace = True)
df.tail()
# Out:
#     Year  Release per year
# 60  2017              7593
# 61  2018              8874
# 65  2021              9022
# 63  2020              9741
# 62  2019             10245

# %% [markdown]
# From the above we can see that most released in 2019, then we can plot the graph

# %%
x = years
y =year_count
fig,ax = plt.subplots()
ax.plot(x,y,linewidth = 3.0)
plt.show()
